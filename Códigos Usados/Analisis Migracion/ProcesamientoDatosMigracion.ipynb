# %%
import pandas as pd

# Lee el archivo Parquet
df2014 = pd.read_parquet('/content/2014.parquet')
df2015 = pd.read_parquet('/content/2015.parquet')
df2016 = pd.read_parquet('/content/2016.parquet')
df2017 = pd.read_parquet('/content/2017.parquet')
df2018 = pd.read_parquet('/content/2018.parquet')
df2019 = pd.read_parquet('/content/2019.parquet')
df2021 = pd.read_parquet('/content/2021.parquet')
df2022 = pd.read_parquet('/content/2022.parquet')
df2023 = pd.read_parquet('/content/2023.parquet')
df2024 = pd.read_parquet('/content/2024 (1).parquet')

# %%
import pandas as pd
import numpy as np

# Reemplazar "sin especificar" con NaN
df2014.replace("Sin Especificar", np.nan, inplace=True)

# Eliminar filas que tengan NaN en cualquier columna
df2014 = df2014.dropna()

# Mostrar las primeras filas del DataFrame limpio para verificar
print(df2014.head())
# Out:
#    cantidad_de_filas agnio               region_destino  \
# 0                  1  2014  América Central y el Caribe
# 1                 17  2014              América del Sur
# 2                  1  2014              América del Sur
# 3                  1  2014              América del Sur
# 4                  1  2014                       África
#
#            region_nacionalidad entrada_salida       sexo categoria_migratoria  \
# 0  América Central y el Caribe       Entradas  Masculino   Visitante Temporal
# 1              América del Sur        Salidas   Femenino              Turismo
# 2                       Europa        Salidas  Masculino  Temporal Estudiante
# 3              América del Sur       Entradas  Masculino  Temporal Trabajador
# 4            América del Norte        Salidas  Masculino            Residente
#
#   motivo_viaje departamento_hospedaje ciudad_hospedaje colombiano_extranjero  \
# 0      Eventos                  Huila            Neiva           Extranjeros
# 1      Turismo              No Aplica        No Aplica           Extranjeros
# 2     Estudios              No Aplica        No Aplica           Extranjeros
# 3      Eventos            Bogota D.C.           Bogotá           Extranjeros
# 4    Residente              No Aplica        No Aplica           Extranjeros
#
#                             puesto_migratorio tipo_transporte  \
# 0               Aeropuerto Eldorado de Bogotá           Aéreo
# 1  Aeropuerto Alfredo Vásquez Cobo de Leticia           Aéreo
# 2    Puesto Migratorio de Rumichaca - Ipiales       Terrestre
# 3               Aeropuerto Eldorado de Bogotá           Aéreo
# 4               Aeropuerto Eldorado de Bogotá           Aéreo
#
#        centro_regional pais_nacionalidad      meses pais_destino_procedencia  \
# 0  Aeropuerto Eldorado        Costa Rica  Diciembre                   Panamá
# 1             Amazonas              Perú     Agosto                     Perú
# 2    Nariño - Putumayo          Alemania    Febrero                  Ecuador
# 3  Aeropuerto Eldorado         Argentina      Marzo                  Bolivia
# 4  Aeropuerto Eldorado            Canadá      Abril                Marruecos
#
#   rango_edad departamento tipo_viajero
# 0      18-29       Bogotá    Visitante
# 1      40-49     Amazonas    Visitante
# 2      18-29       Nariño    Visitante
# 3      40-49       Bogotá    Visitante
# 4      40-49       Bogotá    Residente

# %%
import pandas as pd
import numpy as np

# Reemplazar "sin especificar" con NaN
df2015.replace("Sin Especificar", np.nan, inplace=True)

# Eliminar filas que tengan NaN en cualquier columna
df2015 = df2015.dropna()

# Mostrar las primeras filas del DataFrame limpio para verificar
print(df2015.head())
# Out:
#       cantidad_de_filas agnio     region_destino region_nacionalidad  \
# 737                   1  2015    América del Sur     América del Sur
# 4284                  1  2015  América del Norte     América del Sur
# 4285                  9  2015  América del Norte     América del Sur
# 4286                  1  2015  América del Norte     América del Sur
# 4287                  2  2015  América del Norte     América del Sur
#
#      entrada_salida       sexo categoria_migratoria motivo_viaje  \
# 737        Entradas   Femenino             Negocios      Turismo
# 4284       Entradas  Masculino  Temporal Trabajador      Eventos
# 4285       Entradas  Masculino  Temporal Trabajador      Trabajo
# 4286       Entradas  Masculino           Tripulante  Tripulación
# 4287       Entradas  Masculino              Turismo      Turismo
#
#      departamento_hospedaje ciudad_hospedaje colombiano_extranjero  \
# 737               No Aplica        No Aplica           Colombianos
# 4284            Bogota D.C.           Bogotá           Extranjeros
# 4285            Bogota D.C.           Bogotá           Extranjeros
# 4286            Bogota D.C.           Bogotá           Extranjeros
# 4287              Antioquia         Medellín           Extranjeros
#
#                    puesto_migratorio tipo_transporte      centro_regional  \
# 737   Aeropuerto Matecaña de Pereira           Aéreo         Eje Cafetero
# 4284   Aeropuerto Eldorado de Bogotá           Aéreo  Aeropuerto Eldorado
# 4285   Aeropuerto Eldorado de Bogotá           Aéreo  Aeropuerto Eldorado
# 4286   Aeropuerto Eldorado de Bogotá           Aéreo  Aeropuerto Eldorado
# 4287   Aeropuerto Eldorado de Bogotá           Aéreo  Aeropuerto Eldorado
#
#      pais_nacionalidad  meses pais_destino_procedencia rango_edad  \
# 737           Colombia  Marzo                Venezuela       0-17
# 4284              Perú   Mayo           Estados Unidos      30-39
# 4285         Argentina   Mayo           Estados Unidos      30-39
# 4286           Ecuador   Mayo           Estados Unidos      30-39
# 4287         Argentina   Mayo           Estados Unidos      30-39
#
#      departamento  tipo_viajero
# 737     Risaralda     Visitante
# 4284       Bogotá     Visitante
# 4285       Bogotá     Visitante
# 4286       Bogotá  Otro viajero
# 4287       Bogotá     Visitante

# %%
import pandas as pd
import numpy as np

# Reemplazar "sin especificar" con NaN
df2016.replace("Sin Especificar", np.nan, inplace=True)

# Eliminar filas que tengan NaN en cualquier columna
df2016 = df2016.dropna()
# Out:
#    cantidad_de_filas agnio               region_destino  \
# 0                  1  2014  América Central y el Caribe
# 1                 17  2014              América del Sur
# 2                  1  2014              América del Sur
# 3                  1  2014              América del Sur
# 4                  1  2014                       África
#
#            region_nacionalidad entrada_salida       sexo categoria_migratoria  \
# 0  América Central y el Caribe       Entradas  Masculino   Visitante Temporal
# 1              América del Sur        Salidas   Femenino              Turismo
# 2                       Europa        Salidas  Masculino  Temporal Estudiante
# 3              América del Sur       Entradas  Masculino  Temporal Trabajador
# 4            América del Norte        Salidas  Masculino            Residente
#
#   motivo_viaje departamento_hospedaje ciudad_hospedaje colombiano_extranjero  \
# 0      Eventos                  Huila            Neiva           Extranjeros
# 1      Turismo              No Aplica        No Aplica           Extranjeros
# 2     Estudios              No Aplica        No Aplica           Extranjeros
# 3      Eventos            Bogota D.C.           Bogotá           Extranjeros
# 4    Residente              No Aplica        No Aplica           Extranjeros
#
#                             puesto_migratorio tipo_transporte  \
# 0               Aeropuerto Eldorado de Bogotá           Aéreo
# 1  Aeropuerto Alfredo Vásquez Cobo de Leticia           Aéreo
# 2    Puesto Migratorio de Rumichaca - Ipiales       Terrestre
# 3               Aeropuerto Eldorado de Bogotá           Aéreo
# 4               Aeropuerto Eldorado de Bogotá           Aéreo
#
#        centro_regional pais_nacionalidad      meses pais_destino_procedencia  \
# 0  Aeropuerto Eldorado        Costa Rica  Diciembre                   Panamá
# 1             Amazonas              Perú     Agosto                     Perú
# 2    Nariño - Putumayo          Alemania    Febrero                  Ecuador
# 3  Aeropuerto Eldorado         Argentina      Marzo                  Bolivia
# 4  Aeropuerto Eldorado            Canadá      Abril                Marruecos
#
#   rango_edad departamento tipo_viajero
# 0      18-29       Bogotá    Visitante
# 1      40-49     Amazonas    Visitante
# 2      18-29       Nariño    Visitante
# 3      40-49       Bogotá    Visitante
# 4      40-49       Bogotá    Residente

# %%
import pandas as pd
import numpy as np

# Reemplazar "sin especificar" con NaN
df2017.replace("Sin Especificar", np.nan, inplace=True)

# Eliminar filas que tengan NaN en cualquier columna
df2017 = df2017.dropna()

# %%
import pandas as pd
import numpy as np

# Reemplazar "sin especificar" con NaN
df2018.replace("Sin Especificar", np.nan, inplace=True)

# Eliminar filas que tengan NaN en cualquier columna
df2018 = df2018.dropna()

# %%
import pandas as pd
import numpy as np

# Reemplazar "sin especificar" con NaN
df2019.replace("Sin Especificar", np.nan, inplace=True)

# Eliminar filas que tengan NaN en cualquier columna
df2019 = df2019.dropna()

# %%
import pandas as pd
import numpy as np

# Reemplazar "sin especificar" con NaN
df2021.replace("Sin Especificar", np.nan, inplace=True)

# Eliminar filas que tengan NaN en cualquier columna
df2021 = df2021.dropna()

# Mostrar las primeras filas del DataFrame limpio para verificar
print(df2021.head())
# Out:
#       cantidad_de_filas agnio               region_destino  \
# 675                   1  2021  América Central y el Caribe
# 876                   1  2021  América Central y el Caribe
# 1163                  1  2021  América Central y el Caribe
# 2214                  1  2021  América Central y el Caribe
# 2215                  1  2021  América Central y el Caribe
#
#      region_nacionalidad entrada_salida      sexo       categoria_migratoria  \
# 675      América del Sur       Entradas  Femenino                    Turismo
# 876      América del Sur       Entradas  Femenino  Permiso Otras Actividades
# 1163     América del Sur       Entradas  Femenino                    Turismo
# 2214     América del Sur       Entradas  Femenino                    Turismo
# 2215     América del Sur       Entradas  Femenino                    Turismo
#
#      motivo_viaje departamento_hospedaje ciudad_hospedaje  \
# 675       Retorno              Santander            Girón
# 876   Tripulación            Bogota D.C.     Bogotá, D.C.
# 1163      Turismo            Bogota D.C.     Bogotá, D.C.
# 2214     Negocios            Bogota D.C.     Bogotá, D.C.
# 2215    Residente            Bogota D.C.     Bogotá, D.C.
#
#      colombiano_extranjero                             puesto_migratorio  \
# 675            Colombianos  Aeropuerto Ernesto Cortissoz de Barranquilla
# 876            Colombianos                 Aeropuerto Eldorado de Bogotá
# 1163           Colombianos                 Aeropuerto Eldorado de Bogotá
# 2214           Colombianos                 Aeropuerto Eldorado de Bogotá
# 2215           Colombianos                 Aeropuerto Eldorado de Bogotá
#
#      tipo_transporte      centro_regional pais_nacionalidad      meses  \
# 675            Aéreo            Atlántico          Colombia  Noviembre
# 876            Aéreo  Aeropuerto Eldorado          Colombia      Abril
# 1163           Aéreo  Aeropuerto Eldorado          Colombia      Abril
# 2214           Aéreo  Aeropuerto Eldorado          Colombia      Enero
# 2215           Aéreo  Aeropuerto Eldorado          Colombia      Enero
#
#      pais_destino_procedencia rango_edad departamento  tipo_viajero
# 675                    Panamá       0-17    Atlantico     Residente
# 876                    México      18-29       Bogotá  Otro viajero
# 1163                   México       0-17       Bogotá     Visitante
# 2214                   Panamá       0-17       Bogotá     Visitante
# 2215                   México       0-17       Bogotá     Residente

# %%
import pandas as pd
import numpy as np

# Reemplazar "sin especificar" con NaN
df2022.replace("Sin Especificar", np.nan, inplace=True)

# Eliminar filas que tengan NaN en cualquier columna
df2022 = df2022.dropna()

# %%
import pandas as pd
import numpy as np

# Reemplazar "sin especificar" con NaN
df2023.replace("Sin Especificar", np.nan, inplace=True)

# Eliminar filas que tengan NaN en cualquier columna
df2023 = df2023.dropna()

# %%
import pandas as pd
import numpy as np

# Reemplazar "sin especificar" con NaN
df2024.replace("Sin Especificar", np.nan, inplace=True)

# Eliminar filas que tengan NaN en cualquier columna
df2024 = df2024.dropna()

# %%
import pandas as pd

# Tomar una muestra aleatoria del 20% de los datos
muestra_df2014 = df2014.sample(frac=0.4, random_state=1)
muestra_df2015 = df2015.sample(frac=0.4, random_state=1)
muestra_df2016 = df2016.sample(frac=0.4, random_state=1)
muestra_df2017 = df2017.sample(frac=0.4, random_state=1)
muestra_df2018 = df2018.sample(frac=0.4, random_state=1)
muestra_df2019 = df2019.sample(frac=0.4, random_state=1)
muestra_df2021 = df2021.sample(frac=0.4, random_state=1)
muestra_df2022 = df2022.sample(frac=0.4, random_state=1)
muestra_df2023 = df2023.sample(frac=0.4, random_state=1)
muestra_df2024 = df2024.sample(frac=0.4, random_state=1)

# %%
import pandas as pd

# Lista de DataFrames para cada año
dataframes = [
    muestra_df2014, muestra_df2015, muestra_df2016, muestra_df2017, muestra_df2018, muestra_df2019,
    muestra_df2021, muestra_df2022, muestra_df2023, muestra_df2024
]

# Unir todos los DataFrames en uno solo
df_completo = pd.concat(dataframes, ignore_index=True)

# Mostrar las primeras filas del DataFrame unido para verificar
print(df_completo.head())
# Out:
#    cantidad_de_filas agnio               region_destino  \
# 0                  1  2014                       Europa
# 1                  1  2014  América Central y el Caribe
# 2                  1  2014              América del Sur
# 3                  1  2014  América Central y el Caribe
# 4                  1  2014              América del Sur
#
#            region_nacionalidad entrada_salida       sexo categoria_migratoria  \
# 0                       Europa        Salidas   Femenino  Temporal Estudiante
# 1            América del Norte       Entradas  Masculino     Temporal Cónyuge
# 2  América Central y el Caribe        Salidas  Masculino   Visitante Temporal
# 3                       Europa        Salidas  Masculino  Temporal Trabajador
# 4              América del Sur       Entradas  Masculino  Temporal Trabajador
#
#        motivo_viaje departamento_hospedaje ciudad_hospedaje  \
# 0          Estudios              No Aplica        No Aplica
# 1  Temporal Cónyuge              Antioquia         Medellín
# 2           Eventos              No Aplica        No Aplica
# 3           Trabajo              No Aplica        No Aplica
# 4           Trabajo           Cundinamarca             Chía
#
#   colombiano_extranjero                            puesto_migratorio  \
# 0           Extranjeros                Aeropuerto Eldorado de Bogotá
# 1           Extranjeros                Aeropuerto Eldorado de Bogotá
# 2           Extranjeros  Puente Internacional Simón Bolívar - Cúcuta
# 3           Extranjeros                Aeropuerto Eldorado de Bogotá
# 4           Extranjeros                Aeropuerto Eldorado de Bogotá
#
#   tipo_transporte      centro_regional pais_nacionalidad       meses  \
# 0           Aéreo  Aeropuerto Eldorado            Italia       Junio
# 1           Aéreo  Aeropuerto Eldorado    Estados Unidos   Noviembre
# 2       Terrestre              Oriente            México       Marzo
# 3           Aéreo  Aeropuerto Eldorado       Reino Unido  Septiembre
# 4           Aéreo  Aeropuerto Eldorado         Argentina     Octubre
#
#   pais_destino_procedencia rango_edad        departamento tipo_viajero
# 0                   Italia       0-17              Bogotá    Visitante
# 1                   México      18-29              Bogotá    Visitante
# 2                Venezuela      30-39  Norte de Santander    Visitante
# 3                   México      30-39              Bogotá    Visitante
# 4                     Perú      40-49              Bogotá    Visitante

# %%
df_completo.shape
# Out:
# (3559325, 20)

# %%
# Filtrar solo las filas donde 'departamento_hospedaje' sea 'Antioquia'
ciudades_antioquia = df_completo[df_completo['departamento_hospedaje'].str.lower() == 'antioquia']

# Obtener los valores únicos de 'ciudad_hospedaje' en el departamento de Antioquia
valores_ciudad_hospedaje = ciudades_antioquia['ciudad_hospedaje'].unique()

# Mostrar los valores únicos
print(valores_ciudad_hospedaje)
# Out:
# ['Medellín' 'Montebello' 'Rionegro' 'Puerto Berrío' 'Abejorral' 'Bello'
#  'Envigado' 'Alejandría' 'Itagüí' 'Andes' 'La Ceja' 'Apartadó' 'Bolivar'
#  'Sabaneta' 'Retiro' 'Chigorodó' 'Girardota' 'Santa Bárbara' 'Copacabana'
#  'Guarne' 'Santafé De Antioquia' 'La Pintada' 'Jericó' 'Peñol' 'Yarumal'
#  'Maceo' 'Sabanalarga' 'Marinilla' 'Turbo' 'Caldas' 'El Carmen De Viboral'
#  'Nechí' 'Donmatías' 'Antioquia' 'Remedios' 'La Estrella' 'San Jerónimo'
#  'Barbosa' 'Guadalupe' 'Santa Rosa De Osos' 'Armenia' 'Caucasia' 'Belmira'
#  'Yondó' 'Venecia' 'Carepa' 'Campamento' 'Caramanta' 'Segovia' 'Abriaquí'
#  'Guatape' 'San Juan De Urabá' 'Cáceres' 'Giraldo' 'San Andrés'
#  'San Rafael' 'Uramita' 'Salgar' 'Ebéjico' 'La Unión' 'Caicedo' 'Támesis'
#  'Cañasgordas' 'Yolombó' 'Caracolí' 'El Santuario' 'Ituango' 'Buriticá'
#  'San Pedro De Los Milagros' 'Necoclí' 'Jardín' 'San Vicente Ferrer'
#  'Olaya' 'San Cristibal' 'Puerto Nare' 'Concepción' 'Nariño' 'Betulia'
#  'Granada' 'Fredonia' 'El Bagre' 'Briceño' 'Amalfi' 'Entrerrios'
#  'Frontino' 'Arboletes' 'Titiribí' 'Angelópolis' 'Amagá' 'Ciudad Bolívar'
#  'Dabeiba' 'Liborina' 'Pueblorrico' 'Cocorná' 'San José De La Montaña'
#  'Puerto Triunfo' 'Sonson' 'Gómez Plata' 'San Luis' 'San Carlos'
#  'San Pedro De Urabá' 'San Roque' 'Urrao' 'Betania' 'Hispania' 'Concordia'
#  'Itagui' 'Sopetrán' 'Santa Rosa de Osos' 'Santafé de Antioquia'
#  'El Carmen de Viboral' 'San Francisco' 'Tarazá' 'Currulao' 'Cisneros'
#  'San José de La Montaña' 'Santo Domingo' 'Vegachí'
#  'San Pedro de Los Milagros' 'Anorí' 'Tarso' 'Murindó' 'Angostura'
#  'Puerto Perales' 'San Juan de Urabá' 'Mutatá' 'San Andrés de Cuerquía'
#  'Carolina' 'Valdivia' 'Peque' 'San Pedro de Uraba' 'Heliconia' 'Argelia'
#  'Toledo' 'Yalí' 'Anza' 'Zaragoza' 'Valparaíso' 'No Aplica']

# %%
# Define las listas de ciudades y países que vamos a filtrar
ciudades_area_metropolitana = [
    'Medellín', 'Itagüí', 'Bello', 'Copacabana', 'La Estrella',
    'Caldas', 'Barbosa', 'Sabaneta', 'Girardota', 'Envigado', 'Itagui'
]
paises_excluidos = ['Colombia', 'Venezuela']




# Muestra las primeras filas del DataFrame filtrado para verificar
print(df_completo.head())
# Out:
#    cantidad_de_filas agnio               region_destino  \
# 0                  1  2014                       Europa
# 1                  1  2014  América Central y el Caribe
# 2                  1  2014              América del Sur
# 3                  1  2014  América Central y el Caribe
# 4                  1  2014              América del Sur
#
#            region_nacionalidad entrada_salida       sexo categoria_migratoria  \
# 0                       Europa        Salidas   Femenino  Temporal Estudiante
# 1            América del Norte       Entradas  Masculino     Temporal Cónyuge
# 2  América Central y el Caribe        Salidas  Masculino   Visitante Temporal
# 3                       Europa        Salidas  Masculino  Temporal Trabajador
# 4              América del Sur       Entradas  Masculino  Temporal Trabajador
#
#        motivo_viaje departamento_hospedaje ciudad_hospedaje  \
# 0          Estudios              No Aplica        No Aplica
# 1  Temporal Cónyuge              Antioquia         Medellín
# 2           Eventos              No Aplica        No Aplica
# 3           Trabajo              No Aplica        No Aplica
# 4           Trabajo           Cundinamarca             Chía
#
#   colombiano_extranjero                            puesto_migratorio  \
# 0           Extranjeros                Aeropuerto Eldorado de Bogotá
# 1           Extranjeros                Aeropuerto Eldorado de Bogotá
# 2           Extranjeros  Puente Internacional Simón Bolívar - Cúcuta
# 3           Extranjeros                Aeropuerto Eldorado de Bogotá
# 4           Extranjeros                Aeropuerto Eldorado de Bogotá
#
#   tipo_transporte      centro_regional pais_nacionalidad       meses  \
# 0           Aéreo  Aeropuerto Eldorado            Italia       Junio
# 1           Aéreo  Aeropuerto Eldorado    Estados Unidos   Noviembre
# 2       Terrestre              Oriente            México       Marzo
# 3           Aéreo  Aeropuerto Eldorado       Reino Unido  Septiembre
# 4           Aéreo  Aeropuerto Eldorado         Argentina     Octubre
#
#   pais_destino_procedencia rango_edad        departamento tipo_viajero
# 0                   Italia       0-17              Bogotá    Visitante
# 1                   México      18-29              Bogotá    Visitante
# 2                Venezuela      30-39  Norte de Santander    Visitante
# 3                   México      30-39              Bogotá    Visitante
# 4                     Perú      40-49              Bogotá    Visitante

# %%
# Filtrar solo las filas donde 'entrada_salida' sea 'Entradas'
df_entradas = df_completo[df_completo['entrada_salida'] == 'Entradas']

# Mostrar las primeras filas del DataFrame filtrado para verificar
print(df_entradas.head())
# Out:
#    cantidad_de_filas agnio               region_destino  \
# 1                  1  2014  América Central y el Caribe
# 4                  1  2014              América del Sur
# 5                  1  2014                       Europa
# 6                  1  2014              América del Sur
# 7                  4  2014  América Central y el Caribe
#
#            region_nacionalidad entrada_salida       sexo categoria_migratoria  \
# 1            América del Norte       Entradas  Masculino     Temporal Cónyuge
# 4              América del Sur       Entradas  Masculino  Temporal Trabajador
# 5              América del Sur       Entradas  Masculino  Temporal Trabajador
# 6  América Central y el Caribe       Entradas  Masculino   Visitante Temporal
# 7                       Europa       Entradas  Masculino   Visitante Temporal
#
#        motivo_viaje departamento_hospedaje ciudad_hospedaje  \
# 1  Temporal Cónyuge              Antioquia         Medellín
# 4           Trabajo           Cundinamarca             Chía
# 5           Trabajo            Bogota D.C.           Bogotá
# 6          Negocios              Antioquia         Medellín
# 7           Eventos            Bogota D.C.           Bogotá
#
#   colombiano_extranjero              puesto_migratorio tipo_transporte  \
# 1           Extranjeros  Aeropuerto Eldorado de Bogotá           Aéreo
# 4           Extranjeros  Aeropuerto Eldorado de Bogotá           Aéreo
# 5           Extranjeros  Aeropuerto Eldorado de Bogotá           Aéreo
# 6           Extranjeros  Aeropuerto Eldorado de Bogotá           Aéreo
# 7           Extranjeros  Aeropuerto Eldorado de Bogotá           Aéreo
#
#        centro_regional pais_nacionalidad      meses pais_destino_procedencia  \
# 1  Aeropuerto Eldorado    Estados Unidos  Noviembre                   México
# 4  Aeropuerto Eldorado         Argentina    Octubre                     Perú
# 5  Aeropuerto Eldorado         Venezuela  Diciembre                Dinamarca
# 6  Aeropuerto Eldorado            México      Marzo                   Brasil
# 7  Aeropuerto Eldorado            Suecia  Noviembre                   México
#
#   rango_edad departamento tipo_viajero
# 1      18-29       Bogotá    Visitante
# 4      40-49       Bogotá    Visitante
# 5      30-39       Bogotá    Visitante
# 6      30-39       Bogotá    Visitante
# 7      30-39       Bogotá    Visitante

# %%
# Filtrar solo las filas donde 'ciudad_hospedaje' esté en el área metropolitana
df_filtrado = df_completo[df_completo['ciudad_hospedaje'].isin(ciudades_area_metropolitana)]

# %%
departamentos_excluidos = ['Boyacá', 'Risaralda', 'Santander']

# %%
# Filtrar solo las filas donde 'ciudad_hospedaje' esté en el área metropolitana
df_filtrado = df_completo[df_completo['departamento_hospedaje'].isin(ciudades_area_metropolitana)]

# %%
df_filtrado
# Out:
#          cantidad_de_filas agnio               region_destino  \
# 1                        1  2014  América Central y el Caribe
# 6                        1  2014              América del Sur
# 36                       8  2014  América Central y el Caribe
# 38                       1  2014            América del Norte
# 47                       1  2014  América Central y el Caribe
# ...                    ...   ...                          ...
# 3559305                  2  2024            América del Norte
# 3559306                  6  2024  América Central y el Caribe
# 3559310                  2  2024            América del Norte
# 3559315                  1  2024                       Europa
# 3559323                  1  2024                       Europa
#
#                  region_nacionalidad entrada_salida       sexo  \
# 1                  América del Norte       Entradas  Masculino
# 6        América Central y el Caribe       Entradas  Masculino
# 36                            Europa       Entradas  Masculino
# 38                            Europa       Entradas  Masculino
# 47       América Central y el Caribe       Entradas  Masculino
# ...                              ...            ...        ...
# 3559305            América del Norte       Entradas   Femenino
# 3559306              América del Sur       Entradas   Femenino
# 3559310                      Oceanía       Entradas  Masculino
# 3559315                       Europa       Entradas  Masculino
# 3559323                       Europa       Entradas  Masculino
#
#                         categoria_migratoria      motivo_viaje  \
# 1                           Temporal Cónyuge  Temporal Cónyuge
# 6                         Visitante Temporal          Negocios
# 36                                   Turismo           Turismo
# 38                        Visitante Temporal          Negocios
# 47                       Temporal Trabajador           Trabajo
# ...                                      ...               ...
# 3559305  Permiso de Integración y Desarrollo       Conferencia
# 3559306                              Turismo           Turismo
# 3559310                            Residente         Residente
# 3559315                              Turismo           Turismo
# 3559323                              Turismo           Turismo
#
#         departamento_hospedaje ciudad_hospedaje colombiano_extranjero  \
# 1                    Antioquia         Medellín           Extranjeros
# 6                    Antioquia         Medellín           Extranjeros
# 36                   Antioquia         Medellín           Extranjeros
# 38                   Antioquia         Medellín           Extranjeros
# 47                   Antioquia         Medellín           Extranjeros
# ...                        ...              ...                   ...
# 3559305              Antioquia         Medellín           Extranjeros
# 3559306              Antioquia         Medellín           Extranjeros
# 3559310              Antioquia         Medellín           Extranjeros
# 3559315              Antioquia         Medellín           Extranjeros
# 3559323              Antioquia         Medellín           Extranjeros
#
#                                  puesto_migratorio tipo_transporte  \
# 1                    Aeropuerto Eldorado de Bogotá           Aéreo
# 6                    Aeropuerto Eldorado de Bogotá           Aéreo
# 36       Aeropuerto José María Córdova de Rionegro           Aéreo
# 38                   Aeropuerto Eldorado de Bogotá           Aéreo
# 47                   Aeropuerto Eldorado de Bogotá           Aéreo
# ...                                            ...             ...
# 3559305  Aeropuerto José María Córdova de Rionegro           Aéreo
# 3559306  Aeropuerto José María Córdova de Rionegro           Aéreo
# 3559310  Aeropuerto José María Córdova de Rionegro           Aéreo
# 3559315  Aeropuerto José María Córdova de Rionegro           Aéreo
# 3559323              Aeropuerto Eldorado de Bogotá           Aéreo
#
#              centro_regional pais_nacionalidad      meses  \
# 1        Aeropuerto Eldorado    Estados Unidos  Noviembre
# 6        Aeropuerto Eldorado            México      Marzo
# 36                 Antioquia            España     Agosto
# 38       Aeropuerto Eldorado          Alemania      Julio
# 47       Aeropuerto Eldorado            México      Abril
# ...                      ...               ...        ...
# 3559305            Antioquia    Estados Unidos      Enero
# 3559306            Antioquia           Ecuador    Febrero
# 3559310            Antioquia     Nueva Zelanda    Febrero
# 3559315            Antioquia            Grecia      Julio
# 3559323  Aeropuerto Eldorado            España      Junio
#
#         pais_destino_procedencia rango_edad departamento tipo_viajero
# 1                         México      18-29       Bogotá    Visitante
# 6                         Brasil      30-39       Bogotá    Visitante
# 36                        Panamá      50-59    Antioquía    Visitante
# 38                Estados Unidos      40-49       Bogotá    Visitante
# 47                        México      18-29       Bogotá    Visitante
# ...                          ...        ...          ...          ...
# 3559305           Estados Unidos      60-69    Antioquía    Visitante
# 3559306                   Panamá      60-69    Antioquía    Visitante
# 3559310           Estados Unidos      40-49    Antioquía    Residente
# 3559315                   España      60-69    Antioquía    Visitante
# 3559323                 Alemania      30-39       Bogotá    Visitante
#
# [275354 rows x 20 columns]

# %%
# Filtrar para excluir 'colombia' y 'venezuela' en 'pais_nacionalidad' y 'pais_procedencia'
df_filtrado1 = df_filtrado[
    ~df_completo['pais_nacionalidad'].isin(paises_excluidos) &
    ~df_completo['pais_destino_procedencia'].isin(paises_excluidos) &
    ~df_completo['departamento_hospedaje'].isin(departamentos_excluidos)
]
# Out:
# <ipython-input-97-950d374e5431>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_filtrado1 = df_filtrado[

# %%
df_filtrado1
# Out:
#          cantidad_de_filas  agnio region_destino          region_nacionalidad  \
# 1                        1   1970        América            América del Norte
# 6                        1   1970        América  América Central y el Caribe
# 36                       8   1970        América                       Europa
# 38                       1   1970        América                       Europa
# 47                       1   1970        América  América Central y el Caribe
# ...                    ...    ...            ...                          ...
# 3559305                  2   1970        América            América del Norte
# 3559306                  6   1970        América              América del Sur
# 3559310                  2   1970        América                      Oceanía
# 3559315                  1   1970         Europa                       Europa
# 3559323                  1   1970         Europa                       Europa
#
#         entrada_salida       sexo                 categoria_migratoria  \
# 1             Entradas  Masculino                     Temporal Cónyuge
# 6             Entradas  Masculino                   Visitante Temporal
# 36            Entradas  Masculino                              Turismo
# 38            Entradas  Masculino                   Visitante Temporal
# 47            Entradas  Masculino                  Temporal Trabajador
# ...                ...        ...                                  ...
# 3559305       Entradas   Femenino  Permiso de Integración y Desarrollo
# 3559306       Entradas   Femenino                              Turismo
# 3559310       Entradas  Masculino                            Residente
# 3559315       Entradas  Masculino                              Turismo
# 3559323       Entradas  Masculino                              Turismo
#
#              motivo_viaje departamento_hospedaje ciudad_hospedaje  ...  \
# 1        Temporal Cónyuge              Antioquia         Medellín  ...
# 6                Negocios              Antioquia         Medellín  ...
# 36                Turismo              Antioquia         Medellín  ...
# 38               Negocios              Antioquia         Medellín  ...
# 47                Trabajo              Antioquia         Medellín  ...
# ...                   ...                    ...              ...  ...
# 3559305       Conferencia              Antioquia         Medellín  ...
# 3559306           Turismo              Antioquia         Medellín  ...
# 3559310         Residente              Antioquia         Medellín  ...
# 3559315           Turismo              Antioquia         Medellín  ...
# 3559323           Turismo              Antioquia         Medellín  ...
#
#                                  puesto_migratorio tipo_transporte  \
# 1                    Aeropuerto Eldorado de Bogotá           Aéreo
# 6                    Aeropuerto Eldorado de Bogotá           Aéreo
# 36       Aeropuerto José María Córdova de Rionegro           Aéreo
# 38                   Aeropuerto Eldorado de Bogotá           Aéreo
# 47                   Aeropuerto Eldorado de Bogotá           Aéreo
# ...                                            ...             ...
# 3559305  Aeropuerto José María Córdova de Rionegro           Aéreo
# 3559306  Aeropuerto José María Córdova de Rionegro           Aéreo
# 3559310  Aeropuerto José María Córdova de Rionegro           Aéreo
# 3559315  Aeropuerto José María Córdova de Rionegro           Aéreo
# 3559323              Aeropuerto Eldorado de Bogotá           Aéreo
#
#              centro_regional pais_nacionalidad      meses  \
# 1        Aeropuerto Eldorado    Estados Unidos  Noviembre
# 6        Aeropuerto Eldorado            México      Marzo
# 36                 Antioquia            España     Agosto
# 38       Aeropuerto Eldorado          Alemania      Julio
# 47       Aeropuerto Eldorado            México      Abril
# ...                      ...               ...        ...
# 3559305            Antioquia    Estados Unidos      Enero
# 3559306            Antioquia           Ecuador    Febrero
# 3559310            Antioquia     Nueva Zelanda    Febrero
# 3559315            Antioquia            Grecia      Julio
# 3559323  Aeropuerto Eldorado            España      Junio
#
#         pais_destino_procedencia rango_edad departamento tipo_viajero Cluster
# 1                         México      18-29       Bogotá    Visitante       0
# 6                         Brasil      30-39       Bogotá    Visitante       0
# 36                        Panamá      50-59    Antioquía    Visitante       0
# 38                Estados Unidos      40-49       Bogotá    Visitante       0
# 47                        México      18-29       Bogotá    Visitante       2
# ...                          ...        ...          ...          ...     ...
# 3559305           Estados Unidos      60-69    Antioquía    Visitante       0
# 3559306                   Panamá      60-69    Antioquía    Visitante       0
# 3559310           Estados Unidos      40-49    Antioquía    Residente       0
# 3559315                   España      60-69    Antioquía    Visitante       0
# 3559323                 Alemania      30-39       Bogotá    Visitante       0
#
# [244944 rows x 21 columns]

# %%
pip install unidecode
# Out:
# Collecting unidecode
#   Downloading Unidecode-1.3.8-py3-none-any.whl.metadata (13 kB)
# Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 4.6 MB/s eta 0:00:00
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.8

# %%
import pandas as pd
import unicodedata

def quitar_tildes(s):
    return ''.join((c for c in unicodedata.normalize('NFD', s) if unicodedata.category(c) != 'Mn'))

# Aplicar la función a la columna 'pais_procedencia' y convertir a minúsculas
df_filtrado1['pais_nacionalidad'] = df_filtrado1['pais_nacionalidad'].apply(quitar_tildes).str.lower()
# Out:
# <ipython-input-87-38201274dbcf>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado1['pais_nacionalidad'] = df_filtrado1['pais_nacionalidad'].apply(quitar_tildes).str.lower()

# %%
df_filtrado1
# Out:
#          cantidad_de_filas  agnio region_destino          region_nacionalidad  \
# 1                        1   1970        América            América del Norte
# 6                        1   1970        América  América Central y el Caribe
# 36                       8   1970        América                       Europa
# 38                       1   1970        América                       Europa
# 47                       1   1970        América  América Central y el Caribe
# ...                    ...    ...            ...                          ...
# 3559305                  2   1970        América            América del Norte
# 3559306                  6   1970        América              América del Sur
# 3559310                  2   1970        América                      Oceanía
# 3559315                  1   1970         Europa                       Europa
# 3559323                  1   1970         Europa                       Europa
#
#         entrada_salida       sexo                 categoria_migratoria  \
# 1             Entradas  Masculino                     Temporal Cónyuge
# 6             Entradas  Masculino                   Visitante Temporal
# 36            Entradas  Masculino                              Turismo
# 38            Entradas  Masculino                   Visitante Temporal
# 47            Entradas  Masculino                  Temporal Trabajador
# ...                ...        ...                                  ...
# 3559305       Entradas   Femenino  Permiso de Integración y Desarrollo
# 3559306       Entradas   Femenino                              Turismo
# 3559310       Entradas  Masculino                            Residente
# 3559315       Entradas  Masculino                              Turismo
# 3559323       Entradas  Masculino                              Turismo
#
#              motivo_viaje departamento_hospedaje ciudad_hospedaje  ...  \
# 1        Temporal Cónyuge              Antioquia         Medellín  ...
# 6                Negocios              Antioquia         Medellín  ...
# 36                Turismo              Antioquia         Medellín  ...
# 38               Negocios              Antioquia         Medellín  ...
# 47                Trabajo              Antioquia         Medellín  ...
# ...                   ...                    ...              ...  ...
# 3559305       Conferencia              Antioquia         Medellín  ...
# 3559306           Turismo              Antioquia         Medellín  ...
# 3559310         Residente              Antioquia         Medellín  ...
# 3559315           Turismo              Antioquia         Medellín  ...
# 3559323           Turismo              Antioquia         Medellín  ...
#
#                                  puesto_migratorio tipo_transporte  \
# 1                    Aeropuerto Eldorado de Bogotá           Aéreo
# 6                    Aeropuerto Eldorado de Bogotá           Aéreo
# 36       Aeropuerto José María Córdova de Rionegro           Aéreo
# 38                   Aeropuerto Eldorado de Bogotá           Aéreo
# 47                   Aeropuerto Eldorado de Bogotá           Aéreo
# ...                                            ...             ...
# 3559305  Aeropuerto José María Córdova de Rionegro           Aéreo
# 3559306  Aeropuerto José María Córdova de Rionegro           Aéreo
# 3559310  Aeropuerto José María Córdova de Rionegro           Aéreo
# 3559315  Aeropuerto José María Córdova de Rionegro           Aéreo
# 3559323              Aeropuerto Eldorado de Bogotá           Aéreo
#
#              centro_regional pais_nacionalidad meses  \
# 1        Aeropuerto Eldorado    estados unidos    11
# 6        Aeropuerto Eldorado            mexico     3
# 36                 Antioquia            espana     8
# 38       Aeropuerto Eldorado          alemania     7
# 47       Aeropuerto Eldorado            mexico     4
# ...                      ...               ...   ...
# 3559305            Antioquia    estados unidos     1
# 3559306            Antioquia           ecuador     2
# 3559310            Antioquia     nueva zelanda     2
# 3559315            Antioquia            grecia     7
# 3559323  Aeropuerto Eldorado            espana     6
#
#          pais_destino_procedencia rango_edad departamento tipo_viajero Cluster
# 1                          México      18-29       Bogotá    Visitante       0
# 6                          Brasil      30-39       Bogotá    Visitante       0
# 36                         Panamá      50-59    Antioquía    Visitante       0
# 38                 Estados Unidos      40-49       Bogotá    Visitante       0
# 47                         México      18-29       Bogotá    Visitante       2
# ...                           ...        ...          ...          ...     ...
# 3559305            Estados Unidos      60-69    Antioquía    Visitante       0
# 3559306                    Panamá      60-69    Antioquía    Visitante       0
# 3559310            Estados Unidos      40-49    Antioquía    Residente       0
# 3559315                    España      60-69    Antioquía    Visitante       0
# 3559323                  Alemania      30-39       Bogotá    Visitante       0
#
# [244944 rows x 21 columns]

# %%
# Exportar a un archivo CSV
# Exportar a un archivo CSV en la carpeta de descargas
df_filtrado1.to_csv('df_filtrado.csv', index=False)

# %%
df_filtrado1['tipo_transporte'].unique()
# Out:
# array(['Aéreo', 'Terrestre', 'Marítimi', 'Marítimo', 'Fluvial'],
#       dtype=object)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Mapeo de los meses en texto a números
meses = {
    'Enero': 1, 'Febrero': 2, 'Marzo': 3, 'Abril': 4, 'Mayo': 5, 'Junio': 6,
    'Julio': 7, 'Agosto': 8, 'Septiembre': 9, 'Octubre': 10, 'Noviembre': 11, 'Diciembre': 12
}

# Asumiendo que 'df' es tu DataFrame y 'agnio' es el año y 'meses' el mes en formato texto
df['mes_numerico'] = df['meses'].map(meses)

# Crear la columna de fecha combinando año y mes numérico
df['fecha'] = pd.to_datetime(df['agnio'].astype(str) + '-' + df['mes_numerico'].astype(str), format='%Y-%m')

# Agrupar por la nueva columna 'fecha' y contar las visitas
visitas_por_fecha = df.groupby('fecha').size()

# Extraer solo el mes para el eje X
meses_str = visitas_por_fecha.index.month_name()

# Crear el gráfico de serie temporal
plt.figure(figsize=(14, 6))
sns.lineplot(x=meses_str, y=visitas_por_fecha.values, marker='o', color='b')
plt.title("Frecuencia de Visitas por Mes (Serie de Tiempo)")
plt.xlabel("Mes")
plt.ylabel("Cantidad de Visitas")
plt.xticks(rotation=45)
plt.grid()
plt.show()
# Out:
# <ipython-input-105-190c43a34ecb>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mes_numerico'] = df['meses'].map(meses)
# <ipython-input-105-190c43a34ecb>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fecha'] = pd.to_datetime(df['agnio'].astype(str) + '-' + df['mes_numerico'].astype(str), format='%Y-%m')

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Descomponer la serie de tiempo
descomposicion = seasonal_decompose(visitas_por_fecha, model='additive', period=6)
descomposicion.plot()
plt.show()

# %% [markdown]
# Se puede observar que la frecuencia de visita se asemeja a las festividades importantes de la ciudad como la feria de flores y los alumbrados navideños, esto nos lleva a reflexionar. Ya que si seguimos incentivando eventos importantes en la ciudad se puede seguir fomentando las visitas.

# %%
import matplotlib.pyplot as plt
import pandas as pd
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Asegúrate de que tus datos 'visitas_por_fecha' tienen una frecuencia temporal definida
# Esto es un ejemplo, usa el índice real de tu conjunto de datos
visitas_por_fecha.index = pd.to_datetime(visitas_por_fecha.index)
visitas_por_fecha = visitas_por_fecha.asfreq('MS')  # 'MS' para frecuencia mensual de inicio de mes

# Ajustar el modelo SARIMA
model = SARIMAX(visitas_por_fecha, order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))  # Ejemplo
model_fit = model.fit()

# Hacer predicciones
predicciones = model_fit.forecast(steps=12)

# Crear un índice de fechas para las predicciones (semanas o meses según la frecuencia)
fecha_inicio = visitas_por_fecha.index[-1]  # Última fecha en el conjunto de entrenamiento
fechas_prediccion = pd.date_range(fecha_inicio, periods=13, freq='MS')[1:]  # Generar las siguientes 12 fechas (sin la última)

# Graficar los resultados
plt.figure(figsize=(10, 6))

# Graficar las visitas originales
plt.plot(visitas_por_fecha, label='Visitas Originales', color='blue')

# Graficar las predicciones
plt.plot(fechas_prediccion, predicciones, label='Predicciones', color='red', linestyle='--')

# Personalizar el gráfico
plt.title('Predicciones de Visitas (SARIMA)')
plt.xlabel('Mes')
plt.ylabel('Visitas')
plt.legend()

# Mostrar el gráfico
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for ARMA and trend. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
